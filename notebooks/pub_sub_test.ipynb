# %%
import requests
import json
from typing import Any
import logging
import sys
import pathlib

from ytmusicapi.parsers import songs

# %%
def set_logger(name: str) -> logging.Logger:
    logger: logging.Logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)
    logger.addHandler(logging.StreamHandler(sys.stdout))
    return logger

def get_dir_absolute_path(dir_name: str) -> pathlib.Path:
    # Assuming you are in the "src" folder
    current_folder: pathlib.Path = pathlib.Path.cwd()

    target_folder_path: pathlib.Path = pathlib.Path()
    for parent in current_folder.parents:
        for potential_folder_path in parent.rglob(dir_name):
            if potential_folder_path.is_dir():
                return potential_folder_path

    return target_folder_path

def get_access_token() -> str:
    """
    Retrieve the spotify access token from spotify api endpoint
    :return: the access token
    """
    response: requests.Response = requests.post(
        url="https://accounts.spotify.com/api/token",
        data="grant_type=client_credentials&client_id=bf621646332d4c9c82c6e6d1fd8a8352&client_secret=0ecda4e3308e4340a26b519d0647b2bf",
        headers={"Content-Type": "application/x-www-form-urlencoded"}
    )
    if response.status_code == 200:
        return response.json()["access_token"]

    return ''

# %%
import yt_dlp
from youtube_search import YoutubeSearch
import pathlib
from datetime import datetime
import shutil

youtube_dl_options: dict[str, str | list[dict[str, str]]] = {
    "quiet": True,
    'format': 'bestaudio/best',
    'embedthumbnail': True,
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }, {
        'key': 'FFmpegMetadata',
    }]
}

def get_song_realease_date_folder(release_date: str, precision: str) -> pathlib.Path:
    release_date_precision_map: dict[str, str] = {
        "year": "%Y",
        "month": "%Y-%m",
        "day": "%Y-%m-%d"
    }
    release_date: datetime = datetime.strptime(release_date, release_date_precision_map[precision])

    return pathlib.Path(release_date.strftime(release_date_precision_map[precision].replace('-', '/')))

def download_song_from_youtube(song_to_search: str, track: dict[str, Any]) -> bool:
    release_path: pathlib.Path = get_song_realease_date_folder(
        release_date=track["track"]["album"]["release_date"],
        precision=track["track"]["album"]["release_date_precision"],
    )
    output_path: pathlib.Path = get_dir_absolute_path("songs") / release_path / track["track"]["id"]

    # create dirs if they do not exist
    output_path.parent.mkdir(parents=True, exist_ok=True)

    if output_path.with_suffix(".mp3").exists():
        logger.debug(f"Skipping {track['track']['id']}. Already downloaded. output_path {output_path}")
        return True
    logger.info(f"To download: {track['track']['id']}")
    # return False

    attempts_left: int = 3
    best_url: str = ""
    while attempts_left > 0:
        try:
            url_suffix = YoutubeSearch(song_to_search, max_results=1).to_dict()[0].get("url_suffix")
            best_url = f"https://www.youtube.com{url_suffix}"
            break
        except IndexError:
            attempts_left -= 1
            logger.debug(f"No valid URLs found for {song_to_search}, trying again ({attempts_left} attempts left).")
        if best_url is None:
            logger.debug(f"No valid URLs found for {song_to_search}, skipping track.")
            continue

    # Run you-get to fetch and download the link's audio
    # print(f"Initiating download for {song_to_search}. url is: {best_url}")
    try:
        with yt_dlp.YoutubeDL(youtube_dl_options | {'outtmpl': str(output_path)}) as ydl:
            ydl.extract_info(best_url, download=True)
        return True
    except Exception as e:
        logger.error(e)
        return False

def get_string_to_search_in_youtube(track: dict[str, Any]) -> str:
    track = track.get("track", {})
    # print(track["id"], track["name"], track["uri"], track["album"], track["artists"])
    to_search: str = " ".join([artist.get("name") for artist in track["artists"]])
    return f"{to_search} - {track.get('name')}"

def move_songs_to_release_date_partition(song: dict[str, Any]) -> None:
    songs_path: pathlib.Path = get_dir_absolute_path("songs")
    original_song_path: pathlib.Path = (songs_path / song["track"]["id"]).with_suffix(".mp3")

    if not original_song_path.exists():
        return

    try:
        release_path: pathlib.Path = get_song_realease_date_folder(
            release_date=song["track"]["album"]["release_date"],
            precision=song["track"]["album"]["release_date_precision"],
        )
        output_path: pathlib.Path = (songs_path / release_path / song["track"]["id"]).with_suffix(".mp3")
    except Exception as e:
        return

    if output_path.exists():
        return

    logger.debug(f'moving song["track"]["id"]')
    output_path.parent.mkdir(parents=True, exist_ok=True)
    shutil.move(original_song_path, output_path)

# %%
logger: logging.Logger = set_logger("spotify api get data")
PLAYLISTS: list[str] = ["31LTVcI9mBggtLVlYRStnJ", "7CqTvaywsSnZHdwujtkfqp"]
PLAYLIST_ID: str = PLAYLISTS[0]
access_token: str = get_access_token()
playlist_info: dict[str, str | list[dict[str, Any]]] = get_playlist_tracks_data(PLAYLIST_ID, access_token)
save_playlist_tracks_data(playlist_info, PLAYLIST_ID)
playlist_info
# Out:
# Fetching playlist tracks for 31LTVcI9mBggtLVlYRStnJ, current offset: 0, total songs: 0, fetching total True, fetched 0 songs
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 0th song
# Fetched 100, total 1155, offset 100, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 100th song
# Fetched 200, total 1155, offset 200, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 200th song
# Fetched 300, total 1155, offset 300, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 300th song
# Fetched 400, total 1155, offset 400, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 400th song
# Fetched 500, total 1155, offset 500, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 500th song
# Fetched 600, total 1155, offset 600, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 600th song
# Fetched 700, total 1155, offset 700, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 700th song
# Fetched 800, total 1155, offset 800, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 800th song
# Fetched 900, total 1155, offset 900, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 900th song
# Fetched 1000, total 1155, offset 1000, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 1000th song
# Fetched 1100, total 1155, offset 1100, length 100
# Fetching tracks from playlist id: 31LTVcI9mBggtLVlYRStnJ starting from the 1100th song
# Fetched 1155, total 1155, offset 1155, length 55
# {'playlist_id': '31LTVcI9mBggtLVlYRStnJ',
#  'num_songs': 1155,
#  'tracks': [{'track': {'album': {'name': 'Room 25',
#      'release_date': '2018-09-14',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1EpyA68dKpjf7jXmQL88Hy', 'name': 'Noname'},
#      {'id': '1ybINI1qPiFbwDXamRtwxD', 'name': 'Smino'},
#      {'id': '7Hjbimq43OgxaBRpFXic4x', 'name': 'Saba'}],
#     'id': '1Ya8UT49Oc3oASVcsDqz60',
#     'name': 'Ace',
#     'uri': 'spotify:track:1Ya8UT49Oc3oASVcsDqz60'}},
#   {'track': {'album': {'name': 'Yes Lawd!',
#      'release_date': '2016-10-21',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6PEMFpe3PTOksdV4ZXUpbE', 'name': 'NxWorries'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '17Zu03OgBVxgLxWmRUyNOJ', 'name': 'Knxwledge'}],
#     'id': '5mtfHX4VyY5D81WMaOHgHV',
#     'name': 'What More Can I Say',
#     'uri': 'spotify:track:5mtfHX4VyY5D81WMaOHgHV'}},
#   {'track': {'album': {'name': 'Lost & Found',
#      'release_date': '2018-06-08',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1CoZyIx7UvdxT5c8UkMzHd', 'name': 'Jorja Smith'}],
#     'id': '3c5gLGgwRrE7sQYSNHCXEj',
#     'name': 'February 3rd',
#     'uri': 'spotify:track:3c5gLGgwRrE7sQYSNHCXEj'}},
#   {'track': {'album': {'name': 'Telefone',
#      'release_date': '2016-07-31',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1EpyA68dKpjf7jXmQL88Hy', 'name': 'Noname'},
#      {'id': '1ybINI1qPiFbwDXamRtwxD', 'name': 'Smino'},
#      {'id': '2TKC2gVUNBUAlFqfLUoaj0', 'name': 'Phoelix'},
#      {'id': '7Hjbimq43OgxaBRpFXic4x', 'name': 'Saba'}],
#     'id': '0EN4QjJqiAufEh6g4xPNvC',
#     'name': 'Shadow Man',
#     'uri': 'spotify:track:0EN4QjJqiAufEh6g4xPNvC'}},
#   {'track': {'album': {'name': 'Ctrl',
#      'release_date': '2017-06-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7tYKF4w9nC0nq9CsPZTHyP', 'name': 'SZA'},
#      {'id': '0Y5tJX1MQlPlqiwlOH1tJY', 'name': 'Travis Scott'}],
#     'id': '0q75NwOoFiARAVp4EXU4Bs',
#     'name': 'Love Galore (feat. Travis Scott)',
#     'uri': 'spotify:track:0q75NwOoFiARAVp4EXU4Bs'}},
#   {'track': {'album': {'name': 'good kid, m.A.A.d city',
#      'release_date': '2012',
#      'release_date_precision': 'year'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'},
#      {'id': '28ExwzUQsvgJooOI0X1mr3', 'name': 'Jay Rock'}],
#     'id': '74tLlkN3rgVzRqQJgPfink',
#     'name': 'Money Trees',
#     'uri': 'spotify:track:74tLlkN3rgVzRqQJgPfink'}},
#   {'track': {'album': {'name': 'Natural Causes',
#      'release_date': '2016-09-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '4utLUGcTvOJFr6aqIJtYWV', 'name': 'Skylar Grey'},
#      {'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '0rI56S1biB0efYypn7eNpP',
#     'name': 'Kill For You',
#     'uri': 'spotify:track:0rI56S1biB0efYypn7eNpP'}},
#   {'track': {'album': {'name': 'Black On Both Sides',
#      'release_date': '1999-10-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0Mz5XE0kb1GBnbLQm2VbcO', 'name': 'Mos Def'},
#      {'id': '0lEssBAxQl2In4RpaB1C2Y', 'name': 'Talib Kweli'}],
#     'id': '0dFnHw0HyFYi28ME8XD1lY',
#     'name': 'Know That',
#     'uri': 'spotify:track:0dFnHw0HyFYi28ME8XD1lY'}},
#   {'track': {'album': {'name': 'Lace It (with Eminem & benny blanco)',
#      'release_date': '2023-12-16',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '4MCBfE4596Uoi2O4DtmEMz', 'name': 'Juice WRLD'},
#      {'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5CiGnKThu5ctn9pBxv7DGa', 'name': 'benny blanco'}],
#     'id': '4qmG24ebshLXtKu9HIShBP',
#     'name': 'Lace It (with Eminem & benny blanco)',
#     'uri': 'spotify:track:4qmG24ebshLXtKu9HIShBP'}},
#   {'track': {'album': {'name': 'The Slim Shady LP',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3guazByz82uD2zHf8q7As1',
#     'name': 'Rock Bottom',
#     'uri': 'spotify:track:3guazByz82uD2zHf8q7As1'}},
#   {'track': {'album': {'name': 'Song 32',
#      'release_date': '2019-04-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1EpyA68dKpjf7jXmQL88Hy', 'name': 'Noname'}],
#     'id': '7Duz1lXRfECWROhjHQ5dWk',
#     'name': 'Song 32',
#     'uri': 'spotify:track:7Duz1lXRfECWROhjHQ5dWk'}},
#   {'track': {'album': {'name': 'Dinner Party: Dessert',
#      'release_date': '2020-10-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7MNEVabc4cs19CbzAFZmXz', 'name': 'Terrace Martin'},
#      {'id': '5cM1PvItlR21WUyBnsdMcn', 'name': 'Robert Glasper'},
#      {'id': '4s8ZGMVf3OiPktSP4ulpqU', 'name': '9th Wonder'},
#      {'id': '6HQYnRM4OzToCYPpVBInuU', 'name': 'Kamasi Washington'},
#      {'id': '6p70iKebfMSl8zbkiEwOtS', 'name': 'Dinner Party'},
#      {'id': '0huGjMyP507tBCARyzSkrv', 'name': 'Cordae'},
#      {'id': '2TKC2gVUNBUAlFqfLUoaj0', 'name': 'Phoelix'}],
#     'id': '0rjvlFcg4QVi9dDzctDDGD',
#     'name': 'Freeze Tag (feat. Cordae & Phoelix)',
#     'uri': 'spotify:track:0rjvlFcg4QVi9dDzctDDGD'}},
#   {'track': {'album': {'name': 'I Put A Spell On You',
#      'release_date': '1965-06-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7G1GBhoKtEPnP86X2PvEYO', 'name': 'Nina Simone'}],
#     'id': '6Rqn2GFlmvmV4w9Ala0I1e',
#     'name': 'Feeling Good',
#     'uri': 'spotify:track:6Rqn2GFlmvmV4w9Ala0I1e'}},
#   {'track': {'album': {'name': 'Lost & Found',
#      'release_date': '2018-06-08',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1CoZyIx7UvdxT5c8UkMzHd', 'name': 'Jorja Smith'}],
#     'id': '1It1TxBK3xIQAB4xJkPevn',
#     'name': 'Blue Lights',
#     'uri': 'spotify:track:1It1TxBK3xIQAB4xJkPevn'}},
#   {'track': {'album': {'name': 'In My Mind',
#      'release_date': '2016-02-19',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '07d5etnpjriczFBB8pxmRe',
#       'name': 'BJ The Chicago Kid'}],
#     'id': '5MjAFPcmrR1DYCgZrXCN4d',
#     'name': "Turnin' Me Up",
#     'uri': 'spotify:track:5MjAFPcmrR1DYCgZrXCN4d'}},
#   {'track': {'album': {'name': 'Ventura',
#      'release_date': '2019-04-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '7gSjFKpVmDgC2MMsnN8CYq', 'name': 'Jazmine Sullivan'}],
#     'id': '1BSZGNpIm2nBt1hWSK2bRp',
#     'name': 'Good Heels (feat. Jazmine Sullivan)',
#     'uri': 'spotify:track:1BSZGNpIm2nBt1hWSK2bRp'}},
#   {'track': {'album': {'name': 'The Miseducation of Lauryn Hill',
#      'release_date': '1998-08-25',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2Mu5NfyYm8n5iTomuKAEHl', 'name': 'Ms. Lauryn Hill'}],
#     'id': '71XhXay6rKPZCVAaDtFlSR',
#     'name': 'Lost Ones',
#     'uri': 'spotify:track:71XhXay6rKPZCVAaDtFlSR'}},
#   {'track': {'album': {'name': 'SOS',
#      'release_date': '2022-12-08',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7tYKF4w9nC0nq9CsPZTHyP', 'name': 'SZA'},
#      {'id': '4Gso3d4CscCijv0lmajZWs', 'name': 'Don Toliver'}],
#     'id': '4NqkE7kRUvMDEdcqD96EDO',
#     'name': 'Used (feat. Don Toliver)',
#     'uri': 'spotify:track:4NqkE7kRUvMDEdcqD96EDO'}},
#   {'track': {'album': {'name': 'Signed, Sealed And Delivered',
#      'release_date': '1970-08-07',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7guDJrEfX3qb6FEbdPA5qi', 'name': 'Stevie Wonder'}],
#     'id': '2eF8pWbiivYsYRpbntYsnc',
#     'name': "Signed, Sealed, Delivered (I'm Yours)",
#     'uri': 'spotify:track:2eF8pWbiivYsYRpbntYsnc'}},
#   {'track': {'album': {'name': 'Aretha Now',
#      'release_date': '1968-06-14',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7nwUJBm0HE4ZxD3f5cy5ok', 'name': 'Aretha Franklin'}],
#     'id': '3NfxSdJnVdon1axzloJgba',
#     'name': 'I Say a Little Prayer',
#     'uri': 'spotify:track:3NfxSdJnVdon1axzloJgba'}},
#   {'track': {'album': {'name': 'United',
#      'release_date': '1967-08-29',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3koiLjNrgRTNbOwViDipeA', 'name': 'Marvin Gaye'},
#      {'id': '75jNCko3SnEMI5gwGqrbb8', 'name': 'Tammi Terrell'}],
#     'id': '7tqhbajSfrz2F7E1Z75ASX',
#     'name': "Ain't No Mountain High Enough",
#     'uri': 'spotify:track:7tqhbajSfrz2F7E1Z75ASX'}},
#   {'track': {'album': {'name': 'I Never Loved a Man the Way I Love You',
#      'release_date': '1967-03-10',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7nwUJBm0HE4ZxD3f5cy5ok', 'name': 'Aretha Franklin'}],
#     'id': '7s25THrKz86DM225dOYwnr',
#     'name': 'Respect',
#     'uri': 'spotify:track:7s25THrKz86DM225dOYwnr'}},
#   {'track': {'album': {'name': 'SOS',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7tYKF4w9nC0nq9CsPZTHyP', 'name': 'SZA'}],
#     'id': '2aJnyNu4PQxQ2lyj5boiMG',
#     'name': 'I Hate U',
#     'uri': 'spotify:track:2aJnyNu4PQxQ2lyj5boiMG'}},
#   {'track': {'album': {'name': 'Room 25',
#      'release_date': '2018-09-14',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1EpyA68dKpjf7jXmQL88Hy', 'name': 'Noname'}],
#     'id': '5rNqaOOSNGrYtMo4sLDXU6',
#     'name': 'Self',
#     'uri': 'spotify:track:5rNqaOOSNGrYtMo4sLDXU6'}},
#   {'track': {'album': {'name': 'The Slim Shady LP (Expanded Edition)',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6DVipHzYsPlIoA0DW8Gmns', 'name': 'Royce Da 5\'9"'}],
#     'id': '5VqSAZujDWDJkQ11Laf9W1',
#     'name': 'Bad Meets Evil',
#     'uri': 'spotify:track:5VqSAZujDWDJkQ11Laf9W1'}},
#   {'track': {'album': {'name': 'Cheat Codes',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2dBj3prW7gP9bCCOIQeDUf', 'name': 'Danger Mouse'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'}],
#     'id': '35cHvlGyHrcCslMJrNP363',
#     'name': 'Sometimes',
#     'uri': 'spotify:track:35cHvlGyHrcCslMJrNP363'}},
#   {'track': {'album': {'name': "Get Rich Or Die Tryin'",
#      'release_date': '2003-02-06',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3q7HBObVc0L8jNeTe5Gofh', 'name': '50 Cent'},
#      {'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6C781pluv3BPxGHHCUJNYc',
#     'name': 'Patiently Waiting',
#     'uri': 'spotify:track:6C781pluv3BPxGHHCUJNYc'}},
#   {'track': {'album': {'name': 'The Master',
#      'release_date': '1999-11-30',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3PyWEKLWI0vHPmoNrIX0QE', 'name': 'Rakim'}],
#     'id': '3x3eRMYIXSbPtMLZxldfE5',
#     'name': 'Uplift',
#     'uri': 'spotify:track:3x3eRMYIXSbPtMLZxldfE5'}},
#   {'track': {'album': {'name': "King's Disease III",
#      'release_date': '2023-04-28',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '5MfCvL6jCTkxPCBQf3OkYH',
#     'name': 'Michael & Quincy',
#     'uri': 'spotify:track:5MfCvL6jCTkxPCBQf3OkYH'}},
#   {'track': {'album': {'name': 'SOS',
#      'release_date': '2022-12-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7tYKF4w9nC0nq9CsPZTHyP', 'name': 'SZA'}],
#     'id': '4iZ4pt7kvcaH6Yo8UoZ4s2',
#     'name': 'Snooze',
#     'uri': 'spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2'}},
#   {'track': {'album': {'name': 'Malibu',
#      'release_date': '2016-01-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'}],
#     'id': '5dnAki4SIAcedhAPdF5l2h',
#     'name': "Heart Don't Stand a Chance",
#     'uri': 'spotify:track:5dnAki4SIAcedhAPdF5l2h'}},
#   {'track': {'album': {'name': 'Malibu',
#      'release_date': '2016-01-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'}],
#     'id': '1l5B9wkjOW9718ZfhepOCd',
#     'name': 'The Bird',
#     'uri': 'spotify:track:1l5B9wkjOW9718ZfhepOCd'}},
#   {'track': {'album': {'name': 'Malibu',
#      'release_date': '2016-01-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'}],
#     'id': '06espoEuN2Ny4UqCYAVOCY',
#     'name': 'Put Me Thru',
#     'uri': 'spotify:track:06espoEuN2Ny4UqCYAVOCY'}},
#   {'track': {'album': {'name': 'Cheat Codes',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2dBj3prW7gP9bCCOIQeDUf', 'name': 'Danger Mouse'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'},
#      {'id': '2P5sC9cVZDToPxyomzF1UH', 'name': 'Joey Bada$$'},
#      {'id': '1z7b1Pr1rSlvWRzsW3HOrS', 'name': 'Russ'},
#      {'id': '0ofvvakxXcRhIy5fgIoB9z', 'name': 'Dylan Cartlidge'}],
#     'id': '26bZSUEaSfyPa4gTsAKxZq',
#     'name': 'Because (feat. Joey Bada$$, Russ, and Dylan Cartlidge)',
#     'uri': 'spotify:track:26bZSUEaSfyPa4gTsAKxZq'}},
#   {'track': {'album': {'name': 'Malibu',
#      'release_date': '2016-01-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'}],
#     'id': '6h5IlvRJ2ZNPloCOdzUmyW',
#     'name': 'Come Down',
#     'uri': 'spotify:track:6h5IlvRJ2ZNPloCOdzUmyW'}},
#   {'track': {'album': {'name': 'Cheat Codes',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2dBj3prW7gP9bCCOIQeDUf', 'name': 'Danger Mouse'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'},
#      {'id': '0bzfPKdbXL5ezYW2z3UGQj', 'name': 'Michael Kiwanuka'}],
#     'id': '4so0c8plnJDYDCZtZCfsHr',
#     'name': 'Aquamarine (feat. Michael Kiwanuka)',
#     'uri': 'spotify:track:4so0c8plnJDYDCZtZCfsHr'}},
#   {'track': {'album': {'name': 'Intimidated',
#      'release_date': '2021-11-19',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6qgnBH6iDM91ipVXv28OMu', 'name': 'KAYTRANADA'},
#      {'id': '3Y7RZ31TRPVadSFVy1o8os', 'name': 'H.E.R.'}],
#     'id': '0dFdGPVLs3k0z9ezYWZzUa',
#     'name': 'Intimidated (feat. H.E.R.)',
#     'uri': 'spotify:track:0dFdGPVLs3k0z9ezYWZzUa'}},
#   {'track': {'album': {'name': 'Cheat Codes',
#      'release_date': '2022-08-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2dBj3prW7gP9bCCOIQeDUf', 'name': 'Danger Mouse'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'},
#      {'id': '2pAWfrd7WFF3XhVt9GooDL', 'name': 'MF DOOM'}],
#     'id': '0icFJI44Ub8pJ5Wi77OKFF',
#     'name': 'Belize (feat. MF DOOM)',
#     'uri': 'spotify:track:0icFJI44Ub8pJ5Wi77OKFF'}},
#   {'track': {'album': {'name': 'Tana Talk 4',
#      'release_date': '2022-03-11',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5Matrg5du62bXwer29cU5T', 'name': 'Benny The Butcher'},
#      {'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'}],
#     'id': '59ClUavkkfRhryajZBn2Lf',
#     'name': "Johnny P's Caddy",
#     'uri': 'spotify:track:59ClUavkkfRhryajZBn2Lf'}},
#   {'track': {'album': {'name': 'Demon Days',
#      'release_date': '2005-05-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3AA28KZvwAUcZuOKwyblJQ', 'name': 'Gorillaz'}],
#     'id': '0d28khcov6AiegSCpG5TuT',
#     'name': 'Feel Good Inc.',
#     'uri': 'spotify:track:0d28khcov6AiegSCpG5TuT'}},
#   {'track': {'album': {'name': 'The Score (Expanded Edition)',
#      'release_date': '1996-02-13',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2WKdxPFRD7IqZvlIAvhMgY', 'name': 'Fugees'},
#      {'id': '2Mu5NfyYm8n5iTomuKAEHl', 'name': 'Ms. Lauryn Hill'}],
#     'id': '0Q0IVlqMV64kNLlwjPj0Hl',
#     'name': 'Killing Me Softly With His Song',
#     'uri': 'spotify:track:0Q0IVlqMV64kNLlwjPj0Hl'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Expanded Edition)',
#      'release_date': '2023-11-03',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5Fc4E9FtAoP4UHXWh6oLpS', 'name': 'Buckshot'}],
#     'id': '1fa7bRXO9pZI8kkLZVZywf',
#     'name': "Don't Front",
#     'uri': 'spotify:track:1fa7bRXO9pZI8kkLZVZywf'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP',
#      'release_date': '2000-05-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '3drEaBmm4UexsiDfz5AzXV', 'name': 'RBX'},
#      {'id': '6NFWb2y6S7PH2yvs5xbO2y', 'name': 'Sticky Fingaz'}],
#     'id': '7996f9NZeypc4jqfc6hJUa',
#     'name': 'Remember Me?',
#     'uri': 'spotify:track:7996f9NZeypc4jqfc6hJUa'}},
#   {'track': {'album': {'name': 'The Eminem Show',
#      'release_date': '2002-05-26',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5Qi4Bb7a8C0a00NZcA77L0', 'name': 'D12'}],
#     'id': '73qINA7ccO03wxD8nsJalr',
#     'name': 'When The Music Stops',
#     'uri': 'spotify:track:73qINA7ccO03wxD8nsJalr'}},
#   {'track': {'album': {'name': 'good kid, m.A.A.d city (Deluxe)',
#      'release_date': '2012',
#      'release_date_precision': 'year'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'}],
#     'id': '69pkT3GewmjhQf6vQWcK2L',
#     'name': "Sing About Me, I'm Dying Of Thirst",
#     'uri': 'spotify:track:69pkT3GewmjhQf6vQWcK2L'}},
#   {'track': {'album': {'name': 'The Miseducation of Lauryn Hill',
#      'release_date': '1998-08-25',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2Mu5NfyYm8n5iTomuKAEHl', 'name': 'Ms. Lauryn Hill'}],
#     'id': '0uEp9E98JB5awlA084uaIg',
#     'name': 'Doo Wop (That Thing)',
#     'uri': 'spotify:track:0uEp9E98JB5awlA084uaIg'}},
#   {'track': {'album': {'name': 'Center of Attention',
#      'release_date': '2017-03-24',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3BeQqzKdlARoOd6y30kCO2', 'name': 'Pete Rock'},
#      {'id': '5gv2yt9ii2nJ2tu39FPigj', 'name': 'InI'}],
#     'id': '38pArvbN27FARVwWDviYOJ',
#     'name': 'Square One',
#     'uri': 'spotify:track:38pArvbN27FARVwWDviYOJ'}},
#   {'track': {'album': {'name': "What's Going On",
#      'release_date': '1971-05-21',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3koiLjNrgRTNbOwViDipeA', 'name': 'Marvin Gaye'}],
#     'id': '3Um9toULmYFGCpvaIPFw7l',
#     'name': "What's Going On",
#     'uri': 'spotify:track:3Um9toULmYFGCpvaIPFw7l'}},
#   {'track': {'album': {'name': "What's Going On",
#      'release_date': '1971-05-21',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3koiLjNrgRTNbOwViDipeA', 'name': 'Marvin Gaye'}],
#     'id': '3IDc87lrpEHWFBASmgTgFV',
#     'name': 'Mercy Mercy Me (The Ecology)',
#     'uri': 'spotify:track:3IDc87lrpEHWFBASmgTgFV'}},
#   {'track': {'album': {'name': 'Good Thing',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3qnGvpP8Yth1AqSBMqON5x', 'name': 'Leon Bridges'}],
#     'id': '7FxzgizJRGTQ3fxUqfvljg',
#     'name': 'Bad Bad News',
#     'uri': 'spotify:track:7FxzgizJRGTQ3fxUqfvljg'}},
#   {'track': {'album': {'name': "Mama's Gun",
#      'release_date': '2000-10-31',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7IfculRW2WXyzNQ8djX8WX', 'name': 'Erykah Badu'}],
#     'id': '7pv80uUHfocFqfTytu1MVi',
#     'name': "Didn't Cha Know",
#     'uri': 'spotify:track:7pv80uUHfocFqfTytu1MVi'}},
#   {'track': {'album': {'name': 'Dreamer',
#      'release_date': '1974-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '48nwxUvPJZkm8uPa7xMzmj',
#       'name': 'Bobby "Blue" Bland'}],
#     'id': '4qYHnP5AmKzXbJhciPV8si',
#     'name': "Ain't No Love In The Heart Of The City - Single Version",
#     'uri': 'spotify:track:4qYHnP5AmKzXbJhciPV8si'}},
#   {'track': {'album': {'name': 'Mr. Morale & The Big Steppers',
#      'release_date': '2022-05-13',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'}],
#     'id': '6BU1RZexmvJcBjgagVVt3M',
#     'name': 'Count Me Out',
#     'uri': 'spotify:track:6BU1RZexmvJcBjgagVVt3M'}},
#   {'track': {'album': {'name': 'All Eyez On Me',
#      'release_date': '1996-02-13',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1ZwdS5xdxEREPySFridCfh', 'name': '2Pac'},
#      {'id': '5J32qSlWzKCdcL31B8wglv', 'name': 'Big Syke'}],
#     'id': '4VQNCzfZ3MdHEwwErNXpBo',
#     'name': 'All Eyez On Me (ft. Big Syke)',
#     'uri': 'spotify:track:4VQNCzfZ3MdHEwwErNXpBo'}},
#   {'track': {'album': {'name': 'Relapse: Refill',
#      'release_date': '2009-05-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6DPYiyq5kWVQS4RGwxzPC7', 'name': 'Dr. Dre'},
#      {'id': '3q7HBObVc0L8jNeTe5Gofh', 'name': '50 Cent'}],
#     'id': '4dK00wCxlqWEeN8BoM1BHT',
#     'name': 'Crack A Bottle',
#     'uri': 'spotify:track:4dK00wCxlqWEeN8BoM1BHT'}},
#   {'track': {'album': {'name': 'The Love Movement',
#      'release_date': '1998-09-29',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '09hVIj6vWgoCDtT03h8ZCa',
#       'name': 'A Tribe Called Quest'}],
#     'id': '2MAaiV0bbeq4FpSwPe2rR8',
#     'name': 'Find a Way',
#     'uri': 'spotify:track:2MAaiV0bbeq4FpSwPe2rR8'}},
#   {'track': {'album': {'name': 'Do You Want More?!!!??!',
#      'release_date': '1995-01-17',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '78xUyw6FkVZrRAtziFdtdu', 'name': 'The Roots'}],
#     'id': '7v7tFiNePGwLOrB2tAW3kg',
#     'name': 'Mellow My Man',
#     'uri': 'spotify:track:7v7tFiNePGwLOrB2tAW3kg'}},
#   {'track': {'album': {'name': 'Genesis',
#      'release_date': '2016-03-25',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6vHBuUxrcpn1do5UaEJ7g6', 'name': 'Domo Genesis'},
#      {'id': '4LLpKhyESsyAXpc4laK94U', 'name': 'Mac Miller'}],
#     'id': '1WsRuvitfegWXQJKRgRZrj',
#     'name': 'Coming Back (feat. Mac Miller)',
#     'uri': 'spotify:track:1WsRuvitfegWXQJKRgRZrj'}},
#   {'track': {'album': {'name': 'Unacceptable',
#      'release_date': '2022-08-11',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0huGjMyP507tBCARyzSkrv', 'name': 'Cordae'}],
#     'id': '5aUJonYqwhmvgNlWQdH6P1',
#     'name': 'So With That',
#     'uri': 'spotify:track:5aUJonYqwhmvgNlWQdH6P1'}},
#   {'track': {'album': {'name': 'War & Leisure',
#      'release_date': '2017-12-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '360IAlyVv4PCEVjgyMZrxK', 'name': 'Miguel'},
#      {'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'},
#      {'id': '0rlS0SzVFk8BoiAW0fGBbN', 'name': 'Salaam Remi'}],
#     'id': '1m8WpLYXEiNVZchsWEcCSy',
#     'name': 'Come Through and Chill (feat. J. Cole & Salaam Remi)',
#     'uri': 'spotify:track:1m8WpLYXEiNVZchsWEcCSy'}},
#   {'track': {'album': {'name': 'An Evening With Silk Sonic',
#      'release_date': '2021-11-11',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '6PvvGcCY2XtUcSRld1Wilr', 'name': 'Silk Sonic'},
#      {'id': '4frXpPxQQZwbCu3eTGnZEw', 'name': 'Thundercat'},
#      {'id': '5K0rbdBrs2tNXe5LeWMATT', 'name': 'Bootsy Collins'}],
#     'id': '3jiKUMXqwEodB7gVv1RMZU',
#     'name': 'After Last Night (with Thundercat & Bootsy Collins)',
#     'uri': 'spotify:track:3jiKUMXqwEodB7gVv1RMZU'}},
#   {'track': {'album': {'name': 'So Slow (feat. Anderson .Paak & King Chip)',
#      'release_date': '2015-09-02',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1hFXEoLCso0TI0QvWJdukg', 'name': 'Blended Babies'},
#      {'id': '5NjUjtjtkzZqRuWFdspT1K', 'name': 'King Chip'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'}],
#     'id': '6fYr27d1dxrs2tiYW3nOdN',
#     'name': 'So Slow (feat. Anderson .Paak, King Chip)',
#     'uri': 'spotify:track:6fYr27d1dxrs2tiYW3nOdN'}},
#   {'track': {'album': {'name': '4 Your Eyez Only',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'}],
#     'id': '3pjUyVbFmM96tYhSaKJwTt',
#     'name': 'Change',
#     'uri': 'spotify:track:3pjUyVbFmM96tYhSaKJwTt'}},
#   {'track': {'album': {'name': 'An Evening With Silk Sonic',
#      'release_date': '2021-11-11',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '6PvvGcCY2XtUcSRld1Wilr', 'name': 'Silk Sonic'}],
#     'id': '3a6FcTyvSf0ED3VXeH3PJ5',
#     'name': 'Fly As Me',
#     'uri': 'spotify:track:3a6FcTyvSf0ED3VXeH3PJ5'}},
#   {'track': {'album': {'name': 'An Evening With Silk Sonic',
#      'release_date': '2021-11-11',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '6PvvGcCY2XtUcSRld1Wilr', 'name': 'Silk Sonic'}],
#     'id': '5f7UJCMrA1VRLvbPrq1h0G',
#     'name': 'Put On A Smile',
#     'uri': 'spotify:track:5f7UJCMrA1VRLvbPrq1h0G'}},
#   {'track': {'album': {'name': 'Yes Lawd!',
#      'release_date': '2016-10-21',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6PEMFpe3PTOksdV4ZXUpbE', 'name': 'NxWorries'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '17Zu03OgBVxgLxWmRUyNOJ', 'name': 'Knxwledge'}],
#     'id': '02sagHhK9h0nODtzjF33yP',
#     'name': 'Lyk Dis',
#     'uri': 'spotify:track:02sagHhK9h0nODtzjF33yP'}},
#   {'track': {'album': {'name': 'The Art Of Storytelling',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1W9qOBYRTfP7HcizWN43G1', 'name': 'Slick Rick'},
#      {'id': '1G9G7WwrXka3Z1r7aIDjI7', 'name': 'Outkast'}],
#     'id': '4TGHOWSNAwUXn5onDQr0P1',
#     'name': "Street Talkin'",
#     'uri': 'spotify:track:4TGHOWSNAwUXn5onDQr0P1'}},
#   {'track': {'album': {'name': 'To Pimp A Butterfly',
#      'release_date': '2015-03-16',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'},
#      {'id': '4jCbgl5Dmt3uOh8WRQfpPs', 'name': 'Bilal'},
#      {'id': '0N41KJ4H6bkPAm2tx7VS8C', 'name': 'Anna Wise'},
#      {'id': '4frXpPxQQZwbCu3eTGnZEw', 'name': 'Thundercat'}],
#     'id': '7uWVT3UkCAZyANvv0bdyQn',
#     'name': 'These Walls',
#     'uri': 'spotify:track:7uWVT3UkCAZyANvv0bdyQn'}},
#   {'track': {'album': {'name': 'The Anthology',
#      'release_date': '1999-10-26',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '09hVIj6vWgoCDtT03h8ZCa',
#       'name': 'A Tribe Called Quest'}],
#     'id': '5N5fp1lYSORdZbWanACki9',
#     'name': 'Bonita Applebum',
#     'uri': 'spotify:track:5N5fp1lYSORdZbWanACki9'}},
#   {'track': {'album': {'name': 'Revenge Of The Dreamers III',
#      'release_date': '2019-07-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1iNqsUDUraNWrj00bqssQG', 'name': 'Dreamville'},
#      {'id': '5MbNzCW3qokGyoo9giHA3V', 'name': 'EARTHGANG'},
#      {'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'},
#      {'id': '1ybINI1qPiFbwDXamRtwxD', 'name': 'Smino'},
#      {'id': '7Hjbimq43OgxaBRpFXic4x', 'name': 'Saba'}],
#     'id': '7wTA0NKIm6T7nP2kaymU2a',
#     'name': 'Sacrifices (with EARTHGANG & J. Cole feat. Smino & Saba)',
#     'uri': 'spotify:track:7wTA0NKIm6T7nP2kaymU2a'}},
#   {'track': {'album': {'name': 'Things Fall Apart',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '78xUyw6FkVZrRAtziFdtdu', 'name': 'The Roots'}],
#     'id': '6KyFxGHY8Q5Pkgb05KZoQL',
#     'name': 'Step Into The Relm',
#     'uri': 'spotify:track:6KyFxGHY8Q5Pkgb05KZoQL'}},
#   {'track': {'album': {'name': 'Chilombo',
#      'release_date': '2020-03-06',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5ZS223C6JyBfXasXxrRqOk', 'name': 'Jhené Aiko'},
#      {'id': '3Y7RZ31TRPVadSFVy1o8os', 'name': 'H.E.R.'}],
#     'id': '63wx9vdskaXbYxyDx4oJCZ',
#     'name': 'B.S. (feat. H.E.R.)',
#     'uri': 'spotify:track:63wx9vdskaXbYxyDx4oJCZ'}},
#   {'track': {'album': {'name': 'Things Fall Apart',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '78xUyw6FkVZrRAtziFdtdu', 'name': 'The Roots'},
#      {'id': '3nmiIgeri4vEY7y0VpbsCn', 'name': 'DJ Jazzy Jeff'},
#      {'id': '4o6gZFD9CkUCVzYqrDR3wV', 'name': 'Jazzyfatnastees'}],
#     'id': '0NSYVDo4ryxNWln7TfEyex',
#     'name': 'The Next Movement',
#     'uri': 'spotify:track:0NSYVDo4ryxNWln7TfEyex'}},
#   {'track': {'album': {'name': 'To Pimp A Butterfly',
#      'release_date': '2015-03-16',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'}],
#     'id': '0N3W5peJUQtI4eyR6GJT5O',
#     'name': 'King Kunta',
#     'uri': 'spotify:track:0N3W5peJUQtI4eyR6GJT5O'}},
#   {'track': {'album': {'name': 'Things Fall Apart',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '78xUyw6FkVZrRAtziFdtdu', 'name': 'The Roots'},
#      {'id': '7df4aW2MDoNsEhmJ2NRoro', 'name': 'Dice Raw'},
#      {'id': '0tCtGc5vt29zFZp6KXzN50', 'name': 'Beanie Sigel'}],
#     'id': '17mXHt73LCLF252X533SEK',
#     'name': 'Adrenaline!',
#     'uri': 'spotify:track:17mXHt73LCLF252X533SEK'}},
#   {'track': {'album': {'name': 'Magic 3',
#      'release_date': '2023-09-14',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '2Ikg6hRQOa6e29sq5xWhM8',
#     'name': 'Fever',
#     'uri': 'spotify:track:2Ikg6hRQOa6e29sq5xWhM8'}},
#   {'track': {'album': {'name': 'The Essentials',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3Mcii5XWf6E0lrY3Uky4cA', 'name': 'Ice Cube'}],
#     'id': '2MuJbBWAVewREJmB8WdGJ3',
#     'name': 'It Was A Good Day',
#     'uri': 'spotify:track:2MuJbBWAVewREJmB8WdGJ3'}},
#   {'track': {'album': {'name': 'Cypress Hill',
#      'release_date': '1991-08-13',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '4P0dddbxPil35MNN9G2MEX', 'name': 'Cypress Hill'}],
#     'id': '6l4wMAXzI8RxIysQMYZY0w',
#     'name': 'How I Could Just Kill a Man',
#     'uri': 'spotify:track:6l4wMAXzI8RxIysQMYZY0w'}},
#   {'track': {'album': {'name': 'MIDDLE CHILD',
#      'release_date': '2019-01-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'}],
#     'id': '2JvzF1RMd7lE3KmFlsyZD8',
#     'name': 'MIDDLE CHILD',
#     'uri': 'spotify:track:2JvzF1RMd7lE3KmFlsyZD8'}},
#   {'track': {'album': {'name': '"Awaken, My Love!"',
#      'release_date': '2016-12-02',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '73sIBHcqh3Z3NyqHKZ7FOL', 'name': 'Childish Gambino'}],
#     'id': '0WtDGnWL2KrMCk0mI1Gpwz',
#     'name': 'Redbone',
#     'uri': 'spotify:track:0WtDGnWL2KrMCk0mI1Gpwz'}},
#   {'track': {'album': {'name': 'Electric Dusk',
#      'release_date': '2023-08-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0nnBZ8FXWjG9wZgM2cpfeb', 'name': 'Leon Thomas'}],
#     'id': '64TJKMfx0QxpuR7rTXL05c',
#     'name': 'Treasure In The Hills',
#     'uri': 'spotify:track:64TJKMfx0QxpuR7rTXL05c'}},
#   {'track': {'album': {'name': 'Music To Be Murdered By - Side B (Deluxe Edition)',
#      'release_date': '2020-12-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6fFfnKGVI6X3lkCr8Qw1g1', 'name': 'KXNG Crooked'},
#      {'id': '6DVipHzYsPlIoA0DW8Gmns', 'name': 'Royce Da 5\'9"'},
#      {'id': '1q13yHC6Syg5Y8iPLrRnCq', 'name': 'Joell Ortiz'}],
#     'id': '7pEDNYd1Lf4xudWGrtVH8b',
#     'name': 'I Will (feat. KXNG Crooked, Royce Da 5\'9" & Joell Ortiz)',
#     'uri': 'spotify:track:7pEDNYd1Lf4xudWGrtVH8b'}},
#   {'track': {'album': {'name': 'Music To Be Murdered By - Side B (Deluxe Edition)',
#      'release_date': '2020-12-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '7xeDETVgMCoPkHU3dXtN9x',
#     'name': 'Farewell',
#     'uri': 'spotify:track:7xeDETVgMCoPkHU3dXtN9x'}},
#   {'track': {'album': {'name': 'Music To Be Murdered By - Side B (Deluxe Edition)',
#      'release_date': '2020-12-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6DVipHzYsPlIoA0DW8Gmns', 'name': 'Royce Da 5\'9"'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'},
#      {'id': '3ZotbHeyVQKxQCPDJuQ4SU', 'name': 'Q-Tip'},
#      {'id': '1WjexdTcXHgvlVIPCE8D1Q', 'name': 'Denaun'}],
#     'id': '6JyvP9BYLtIDXzjZLMNYTR',
#     'name': 'Yah Yah (feat. Royce Da 5\'9", Black Thought, Q-Tip & Denaun)',
#     'uri': 'spotify:track:6JyvP9BYLtIDXzjZLMNYTR'}},
#   {'track': {'album': {'name': 'Below The Heavens',
#      'release_date': '2007-07-17',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '567CChDKZrtF4rnk2r5JeP', 'name': 'Blu & Exile'},
#      {'id': '1KeJhR0ENFviw187pD4LPT', 'name': 'Blu'},
#      {'id': '4r4XYZJUeeKCcrkvi7voDP', 'name': 'Exile'}],
#     'id': '0SPOBDQDwcLFC3hFjqZX5V',
#     'name': 'Dancing In The Rain',
#     'uri': 'spotify:track:0SPOBDQDwcLFC3hFjqZX5V'}},
#   {'track': {'album': {'name': 'Train Of Thought',
#      'release_date': '2000-10-17',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6vwJ3e6KaQAhLEpBPxCMBC',
#       'name': 'Reflection Eternal'}],
#     'id': '0kHIEdWbOvnrvTmRfPtHDN',
#     'name': 'Memories Live',
#     'uri': 'spotify:track:0kHIEdWbOvnrvTmRfPtHDN'}},
#   {'track': {'album': {'name': 'RIP Human Art',
#      'release_date': '2023-09-22',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5MbNzCW3qokGyoo9giHA3V', 'name': 'EARTHGANG'},
#      {'id': '7izarc0fRIPbdZ8cVyChRf', 'name': 'Spillage Village'}],
#     'id': '56Nv3kZNdUPL6BsC1I0jd7',
#     'name': 'Flavors of Karma',
#     'uri': 'spotify:track:56Nv3kZNdUPL6BsC1I0jd7'}},
#   {'track': {'album': {'name': 'Eye Know',
#      'release_date': '1989-03-03',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1Z8ODXyhEBi3WynYw0Rya6', 'name': 'De La Soul'},
#      {'id': '60df5JBRRPcnSpsIMxxwQm', 'name': 'Otis Redding'}],
#     'id': '4sDXEltU35xgga78VFvmJe',
#     'name': 'Eye Know',
#     'uri': 'spotify:track:4sDXEltU35xgga78VFvmJe'}},
#   {'track': {'album': {'name': "Let's Stay Together",
#      'release_date': '1972',
#      'release_date_precision': 'year'},
#     'artists': [{'id': '3dkbV4qihUeMsqN4vBGg93', 'name': 'Al Green'}],
#     'id': '63xdwScd1Ai1GigAwQxE8y',
#     'name': "Let's Stay Together",
#     'uri': 'spotify:track:63xdwScd1Ai1GigAwQxE8y'}},
#   {'track': {'album': {'name': 'So Gold (Immersive Edition)',
#      'release_date': '2023-09-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0XzVyZOZF7FIsQ7VbBZ9Yy', 'name': 'Shafiq Husayn'},
#      {'id': '3jk39CGeaaSO3FPKNx1RUx', 'name': 'Syd'},
#      {'id': '6RiH4it36bTUNBvUjPH2DP', 'name': 'Didda Joe'},
#      {'id': '4cGbWF0MMhak6Ws9ROGC44', 'name': 'August Rose'}],
#     'id': '0cP1OjR8nVm0iA4Zk3EYnC',
#     'name': 'No Particulars',
#     'uri': 'spotify:track:0cP1OjR8nVm0iA4Zk3EYnC'}},
#   {'track': {'album': {'name': 'Paradise',
#      'release_date': '2023-09-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7MNEVabc4cs19CbzAFZmXz', 'name': 'Terrace Martin'},
#      {'id': '7E2ioKxoxI2J94tUkIx6As', 'name': 'Alex Isley'}],
#     'id': '5pBSxjuMqmm9CVPz8RIIPy',
#     'name': 'Paradise',
#     'uri': 'spotify:track:5pBSxjuMqmm9CVPz8RIIPy'}},
#   {'track': {'album': {'name': 'good kid, m.A.A.d city (Deluxe)',
#      'release_date': '2012',
#      'release_date_precision': 'year'},
#     'artists': [{'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'},
#      {'id': '3nFkdlSjzX9mRTtwJOzDYB', 'name': 'JAY-Z'}],
#     'id': '3SImXx6qmobDK2q7MKeR1Z',
#     'name': 'Bitch, Don’t Kill My Vibe - Remix',
#     'uri': 'spotify:track:3SImXx6qmobDK2q7MKeR1Z'}},
#   {'track': {'album': {'name': "People's Instinctive Travels and the Paths of Rhythm (25th Anniversary Edition)",
#      'release_date': '1990-04-17',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '09hVIj6vWgoCDtT03h8ZCa',
#       'name': 'A Tribe Called Quest'}],
#     'id': '7EhEPcPa60LlvGuG9R1DOx',
#     'name': 'Luck of Lucien',
#     'uri': 'spotify:track:7EhEPcPa60LlvGuG9R1DOx'}},
#   {'track': {'album': {'name': 'Misunderstood',
#      'release_date': '2019-03-20',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5gaElx30yTGGiOCVnml29N', 'name': 'Shaé Universe'}],
#     'id': '4f8osgK386WLs1Qntyqx2z',
#     'name': 'Misunderstood',
#     'uri': 'spotify:track:4f8osgK386WLs1Qntyqx2z'}},
#   {'track': {'album': {'name': '1123',
#      'release_date': '2019-07-26',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '07d5etnpjriczFBB8pxmRe', 'name': 'BJ The Chicago Kid'},
#      {'id': '6U3ybJ9UHNKEdsH7ktGBZ7', 'name': 'JID'},
#      {'id': '6PDLwWvgYNMfBRLqC1h5cJ', 'name': 'Buddy'},
#      {'id': '4JgGhWEWcKIyT84mknHP2w', 'name': 'Kent Jamz'}],
#     'id': '0sfDMsYTbwKYNSqd7SPqRn',
#     'name': 'Get Away',
#     'uri': 'spotify:track:0sfDMsYTbwKYNSqd7SPqRn'}},
#   {'track': {'album': {'name': 'An Evening With Silk Sonic',
#      'release_date': '2021-11-12',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0du5cEVh5yTK9QJze8zA0C', 'name': 'Bruno Mars'},
#      {'id': '3jK9MiCrA42lLAdMGUZpwa', 'name': 'Anderson .Paak'},
#      {'id': '6PvvGcCY2XtUcSRld1Wilr', 'name': 'Silk Sonic'}],
#     'id': '4pryE6cN2gFL1FVF5fYINl',
#     'name': 'Leave The Door Open',
#     'uri': 'spotify:track:4pryE6cN2gFL1FVF5fYINl'}},
#   {'track': {'album': {'name': 'Illmatic',
#      'release_date': '1994-04-19',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '7G3lxTsMfSx4yarMkfgnTC',
#     'name': 'The World Is Yours',
#     'uri': 'spotify:track:7G3lxTsMfSx4yarMkfgnTC'}},
#   {'track': {'album': {'name': 'Isolation',
#      'release_date': '2018-04-06',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1U1el3k54VvEUzo3ybLPlM', 'name': 'Kali Uchis'},
#      {'id': '4V8LLVI7PbaPR0K2TGSxFF', 'name': 'Tyler, The Creator'},
#      {'id': '5K0rbdBrs2tNXe5LeWMATT', 'name': 'Bootsy Collins'}],
#     'id': '1otG6j1WHNvl9WgXLWkHTo',
#     'name': 'After The Storm (feat. Tyler, The Creator & Bootsy Collins)',
#     'uri': 'spotify:track:1otG6j1WHNvl9WgXLWkHTo'}},
#   {'track': {'album': {'name': 'Round Trip',
#      'release_date': '2023-06-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5v0XTlB9FqNvfBfnw8n5b0', 'name': 'Statik Selektah'},
#      {'id': '02kJSzxNuaWGqwubyUba0Z', 'name': 'G-Eazy'}],
#     'id': '0JAoQHaj0XY64ElsGshZc2',
#     'name': 'Vanilla Sky',
#     'uri': 'spotify:track:0JAoQHaj0XY64ElsGshZc2'}},
#   {'track': {'album': {'name': 'Die Today',
#      'release_date': '2023-08-30',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5MbNzCW3qokGyoo9giHA3V', 'name': 'EARTHGANG'},
#      {'id': '7izarc0fRIPbdZ8cVyChRf', 'name': 'Spillage Village'}],
#     'id': '2AVrcU1B8cpy66ycCnkYvv',
#     'name': 'Die Today',
#     'uri': 'spotify:track:2AVrcU1B8cpy66ycCnkYvv'}},
#   {'track': {'album': {'name': 'Paid In Full (Deluxe Edition)',
#      'release_date': '1987-07-07',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6jHG1YQkqgojdEzerwvrVv', 'name': 'Eric B. & Rakim'}],
#     'id': '5XQPpKiBjXUI4bIenLBxci',
#     'name': 'Paid In Full - Seven Minutes Of Madness - The Coldcut Remix',
#     'uri': 'spotify:track:5XQPpKiBjXUI4bIenLBxci'}},
#   {'track': {'album': {'name': 'Home',
#      'release_date': '2017-06-30',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '72zigmOdJbIsz0iIRhCBvp', 'name': 'Illa J'}],
#     'id': '7x28d098yqNbcCQPh8JxHz',
#     'name': 'Home',
#     'uri': 'spotify:track:7x28d098yqNbcCQPh8JxHz'}},
#   {'track': {'album': {'name': 'Baduizm',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7IfculRW2WXyzNQ8djX8WX', 'name': 'Erykah Badu'}],
#     'id': '0tNuJpBgtE65diL6Q8Q7fI',
#     'name': 'On & On',
#     'uri': 'spotify:track:0tNuJpBgtE65diL6Q8Q7fI'}},
#   {'track': {'album': {'name': 'Sneakers rap',
#      'release_date': '2000-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '0Mz5XE0kb1GBnbLQm2VbcO', 'name': 'Mos Def'},
#      {'id': '7mrvU3OShTgthJV80o2day', 'name': 'dj honda'}],
#     'id': '4ceCqH1UNZGCa5vRZNDgsj',
#     'name': "Travellin' Man",
#     'uri': 'spotify:track:4ceCqH1UNZGCa5vRZNDgsj'}},
#   {'track': {'album': {'name': 'Nobody But You',
#      'release_date': '2021-04-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2ICR2m4hOBPhaYiZB3rnLW', 'name': 'Sonder'},
#      {'id': '1CoZyIx7UvdxT5c8UkMzHd', 'name': 'Jorja Smith'}],
#     'id': '6VFKuuqSbA1GpMEosUgTwQ',
#     'name': 'Nobody But You',
#     'uri': 'spotify:track:6VFKuuqSbA1GpMEosUgTwQ'}},
#   {'track': {'album': {'name': 'Good to Be Home Barney (feat. Tom Misch, Loyle Carner & Rebel Kleff)',
#      'release_date': '2018-10-02',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5iRM7qYip6UNfQaPe2reCz', 'name': 'Barney Artist'},
#      {'id': '1uiEZYehlNivdK3iQyAbye', 'name': 'Tom Misch'},
#      {'id': '4oDjh8wNW5vDHyFRrDYC4k', 'name': 'Loyle Carner'},
#      {'id': '30hdtITC1smeQbusvnZJnu', 'name': 'Rebel Kleff'}],
#     'id': '0dIgcqNnTDWT3q8DT5KyX3',
#     'name': 'Good to Be Home Barney (feat. Tom Misch, Loyle Carner & Rebel Kleff)',
#     'uri': 'spotify:track:0dIgcqNnTDWT3q8DT5KyX3'}},
#   {'track': {'album': {'name': 'aiMless',
#      'release_date': '2020-04-24',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '4mErKO4g29SXtBwj4S80aB', 'name': 'rum.gold'},
#      {'id': '4UodukR17NIQfNu5uaqm9B', 'name': 'Jamila Woods'}],
#     'id': '02nZeTbm2dRHisH6qsUM5E',
#     'name': 'Waiting For (feat. Jamila Woods)',
#     'uri': 'spotify:track:02nZeTbm2dRHisH6qsUM5E'}},
#   {'track': {'album': {'name': 'Chris Black Changed My Life',
#      'release_date': '2023-06-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '4kI8Ie27vjvonwaB2ePh8T', 'name': 'Portugal. The Man'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'},
#      {'id': '1hcdI2N1023RvSwLzTtdsp', 'name': 'Natalia Lafourcade'}],
#     'id': '6jW0scPonEHW9zjPspVHrn',
#     'name': 'Thunderdome [W.T.A.] (feat. Black Thought & Natalia Lafourcade)',
#     'uri': 'spotify:track:6jW0scPonEHW9zjPspVHrn'}},
#   {'track': {'album': {'name': 'My Bag',
#      'release_date': '2023-06-20',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7h01MzzV4zMo39ocJpJiCi', 'name': 'Lo Village'}],
#     'id': '6W8859vsrvsN4AeppXfkJc',
#     'name': 'My Bag',
#     'uri': 'spotify:track:6W8859vsrvsN4AeppXfkJc'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP',
#      'release_date': '2000-05-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6DPYiyq5kWVQS4RGwxzPC7', 'name': 'Dr. Dre'},
#      {'id': '7hJcb9fa4alzcOq3EaNPoG', 'name': 'Snoop Dogg'},
#      {'id': '4tujQJicOnuZRLiBFdp3Ou', 'name': 'Xzibit'},
#      {'id': '1Oa0bMld0A3u5OTYfMzp5h', 'name': 'Nate Dogg'}],
#     'id': '7lgvU7WnwcNZ8dbGUz8yhP',
#     'name': 'Bitch Please II',
#     'uri': 'spotify:track:7lgvU7WnwcNZ8dbGUz8yhP'}},
#   {'track': {'album': {'name': 'The Plugs I Met',
#      'release_date': '2019-06-21',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '5Matrg5du62bXwer29cU5T', 'name': 'Benny The Butcher'},
#      {'id': '6DJEUXZm0e2rAohdoZ5Voo', 'name': 'Black Thought'}],
#     'id': '0FQeZmAKQLLnZC5iTN6JuR',
#     'name': 'Crowns for Kings (Feat. Black Thought)',
#     'uri': 'spotify:track:0FQeZmAKQLLnZC5iTN6JuR'}},
#   {'track': {'album': {'name': 'The Slim Shady LP',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '1F4lm7DxvpNvXfT3cGuJCb',
#     'name': "Still Don't Give A Fuck",
#     'uri': 'spotify:track:1F4lm7DxvpNvXfT3cGuJCb'}},
#   {'track': {'album': {'name': 'Bizarre Ride II The Pharcyde',
#      'release_date': '1992-11-24',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7yk35uHNQclPXFGFoTU44w', 'name': 'The Pharcyde'}],
#     'id': '4G3dZN9o3o2X4VKwt4CLts',
#     'name': "Passin' Me By",
#     'uri': 'spotify:track:4G3dZN9o3o2X4VKwt4CLts'}},
#   {'track': {'album': {'name': "King's Disease III",
#      'release_date': '2023-04-28',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '4w1bfkfaTMFl3P7JWx2ht3',
#     'name': "I'm on Fire",
#     'uri': 'spotify:track:4w1bfkfaTMFl3P7JWx2ht3'}},
#   {'track': {'album': {'name': "King's Disease III",
#      'release_date': '2023-04-28',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '0hXDGoxfMhhqHZ7l1HprJ4',
#     'name': 'Til My Last Breath - Bonus Track',
#     'uri': 'spotify:track:0hXDGoxfMhhqHZ7l1HprJ4'}},
#   {'track': {'album': {'name': "King's Disease III",
#      'release_date': '2023-04-28',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas'}],
#     'id': '6tSemeCMDHYp5gqmKDJcn2',
#     'name': 'Thun',
#     'uri': 'spotify:track:6tSemeCMDHYp5gqmKDJcn2'}},
#   {'track': {'album': {'name': 'Fall and Rise',
#      'release_date': '2021-04-30',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '2a9f2VimmRYcFvQl06wrw6', 'name': 'Whizzer Dee'},
#      {'id': '2M9OIHcdVSxhPVCYQ3z5Rf', 'name': 'Awon'}],
#     'id': '22PI1zeHO5xpp0Q3CwjY3y',
#     'name': 'Fall and Rise',
#     'uri': 'spotify:track:22PI1zeHO5xpp0Q3CwjY3y'}},
#   {'track': {'album': {'name': 'Support Groups',
#      'release_date': '2022-04-04',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '3UVAHjOF02xcdm22jOzfNP', 'name': 'The Good People'}],
#     'id': '6XRHd6daPD5BWvDlq8joRj',
#     'name': 'Support Groups',
#     'uri': 'spotify:track:6XRHd6daPD5BWvDlq8joRj'}},
#   {'track': {'album': {'name': '2014 Forest Hills Drive',
#      'release_date': '2014-12-09',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '6l3HvQ5sa6mXTsMTB19rO5', 'name': 'J. Cole'}],
#     'id': '0Thqjtu54vKMP06pwZkAWp',
#     'name': 'G.O.M.D',
#     'uri': 'spotify:track:0Thqjtu54vKMP06pwZkAWp'}},
#   {'track': {'album': {'name': 'Labcabincalifornia (Deluxe Edition)',
#      'release_date': '1995-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7yk35uHNQclPXFGFoTU44w', 'name': 'The Pharcyde'}],
#     'id': '0XgpiStoxq1IJncYlPrvZ5',
#     'name': "Runnin'",
#     'uri': 'spotify:track:0XgpiStoxq1IJncYlPrvZ5'}},
#   {'track': {'album': {'name': "'Justments",
#      'release_date': '1974-08-08',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '1ThoqLcyIYvZn7iWbj8fsj', 'name': 'Bill Withers'}],
#     'id': '0S5ZoKKZD3bllkvhEoPimZ',
#     'name': 'Can We Pretend',
#     'uri': 'spotify:track:0S5ZoKKZD3bllkvhEoPimZ'}},
#   {'track': {'album': {'name': 'In Flight',
#      'release_date': '2018-11-09',
#      'release_date_precision': 'day'},
# ...
#   {'track': {'album': {'name': 'Recovery',
#      'release_date': '2010-06-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '1v54pVfqtSC7KbTu2C2pnM',
#     'name': 'You’re Never Over',
#     'uri': 'spotify:track:1v54pVfqtSC7KbTu2C2pnM'}},
#   {'track': {'album': {'name': 'Recovery',
#      'release_date': '2010-06-18',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '44ut2KJnt0HQMnUaMlDv9W',
#     'name': 'Untitled',
#     'uri': 'spotify:track:44ut2KJnt0HQMnUaMlDv9W'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3IaAYtmN8T0YIYVqnxNnVz',
#     'name': 'Bad Guy',
#     'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '7BneCfYRPXAJsEXRdVzEfV',
#     'name': 'Parking Lot - Skit',
#     'uri': 'spotify:track:7BneCfYRPXAJsEXRdVzEfV'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '45JxylFwaThjLsRBuzcfoL',
#     'name': 'Rhyme Or Reason',
#     'uri': 'spotify:track:45JxylFwaThjLsRBuzcfoL'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6dJRP4pXk4SOzWfhfHL3Or',
#     'name': 'So Much Better',
#     'uri': 'spotify:track:6dJRP4pXk4SOzWfhfHL3Or'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3stOygN0I7CIvkEB2LJGbv',
#     'name': 'Survival',
#     'uri': 'spotify:track:3stOygN0I7CIvkEB2LJGbv'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '1mavQ4WCzXSeL2Dm5DS4GQ',
#     'name': 'Legacy',
#     'uri': 'spotify:track:1mavQ4WCzXSeL2Dm5DS4GQ'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '4utLUGcTvOJFr6aqIJtYWV', 'name': 'Skylar Grey'}],
#     'id': '0OOv1XGVVzUgTIzomIHfR0',
#     'name': 'Asshole',
#     'uri': 'spotify:track:0OOv1XGVVzUgTIzomIHfR0'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6Xk7PnitV9jCRorWt2LiVZ',
#     'name': 'Berzerk',
#     'uri': 'spotify:track:6Xk7PnitV9jCRorWt2LiVZ'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6or1bKJiZ06IlK0vFvY75k',
#     'name': 'Rap God',
#     'uri': 'spotify:track:6or1bKJiZ06IlK0vFvY75k'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '5k7wy2Ek7y6kSQ4fER7w0E',
#     'name': 'Brainless',
#     'uri': 'spotify:track:5k7wy2Ek7y6kSQ4fER7w0E'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6MtI49ggHHumUTONlvMQlq',
#     'name': 'Stronger Than I Was',
#     'uri': 'spotify:track:6MtI49ggHHumUTONlvMQlq'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5pKCCKE2ajJHZ9KAiaK11H', 'name': 'Rihanna'}],
#     'id': '48RrDBpOSSl1aLVCalGl5C',
#     'name': 'The Monster',
#     'uri': 'spotify:track:48RrDBpOSSl1aLVCalGl5C'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '0nzsCN9rtXdugPoiIT49Kj',
#     'name': 'So Far...',
#     'uri': 'spotify:track:0nzsCN9rtXdugPoiIT49Kj'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '2YZyLoL8N0Wb9xBt1NhZWg', 'name': 'Kendrick Lamar'}],
#     'id': '0iMN420Q45isZVNlAqzPTW',
#     'name': 'Love Game',
#     'uri': 'spotify:track:0iMN420Q45isZVNlAqzPTW'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '1qUjOF5fzrpoNycD36b2jZ', 'name': 'Nate Ruess'}],
#     'id': '222dTwr5XeEgAzEtsrQA0R',
#     'name': 'Headlights',
#     'uri': 'spotify:track:222dTwr5XeEgAzEtsrQA0R'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3E1BkJEsRK7VsSNzijilGm',
#     'name': 'Evil Twin',
#     'uri': 'spotify:track:3E1BkJEsRK7VsSNzijilGm'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '5sGzBBWPe4YC2YoW7lBYph',
#     'name': 'Baby',
#     'uri': 'spotify:track:5sGzBBWPe4YC2YoW7lBYph'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '2FsZnS8gQ8jG1HGnPYNlm9', 'name': 'Jamie N Commons'}],
#     'id': '01zPnSlKCw9WLbY0kvNep0',
#     'name': 'Desperation',
#     'uri': 'spotify:track:01zPnSlKCw9WLbY0kvNep0'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3fCRPhzGYSd4y6K1qjFcIp',
#     'name': 'Groundhog Day',
#     'uri': 'spotify:track:3fCRPhzGYSd4y6K1qjFcIp'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5WUlDfRSoLAfcVSX1WnrxN', 'name': 'Sia'}],
#     'id': '7hiBhOh4s8G0xmGYBAjyuw',
#     'name': 'Beautiful Pain',
#     'uri': 'spotify:track:7hiBhOh4s8G0xmGYBAjyuw'}},
#   {'track': {'album': {'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '4dfAUJI1QesmK5HfK9gtYs',
#     'name': 'Wicked Ways',
#     'uri': 'spotify:track:4dfAUJI1QesmK5HfK9gtYs'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6vWDO969PvNqNYHIOW5v0m', 'name': 'Beyoncé'}],
#     'id': '7CcoUAtUcYhUfBsmtn0ajO',
#     'name': 'Walk On Water (feat. Beyoncé)',
#     'uri': 'spotify:track:7CcoUAtUcYhUfBsmtn0ajO'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '4iTyf5pLZMOR8YrEZgSopo',
#     'name': 'Believe',
#     'uri': 'spotify:track:4iTyf5pLZMOR8YrEZgSopo'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '0FTrIsp2Mg7Bkf8eXQrISa', 'name': 'PHresher'}],
#     'id': '13aKdwvdGjuZDv2OOKyvs7',
#     'name': 'Chloraseptic (feat. Phresher)',
#     'uri': 'spotify:track:13aKdwvdGjuZDv2OOKyvs7'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6IvespQWGW4USXwexlVKDm',
#     'name': 'Untouchable',
#     'uri': 'spotify:track:6IvespQWGW4USXwexlVKDm'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '6eUKZXaKkcviH0Ku9w2n3V', 'name': 'Ed Sheeran'}],
#     'id': '1cS0TgbR263ey9jn0MwD2s',
#     'name': 'River (feat. Ed Sheeran)',
#     'uri': 'spotify:track:1cS0TgbR263ey9jn0MwD2s'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '2tKJpsRSTxmGAe6TKcstR4',
#     'name': 'Remind Me (Intro)',
#     'uri': 'spotify:track:2tKJpsRSTxmGAe6TKcstR4'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '5uvwJAheJJEkgu88t3Wqf5',
#     'name': 'Remind Me',
#     'uri': 'spotify:track:5uvwJAheJJEkgu88t3Wqf5'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '74dQwVKuCx6aDI2BQ7xW92',
#     'name': 'Revival (Interlude)',
#     'uri': 'spotify:track:74dQwVKuCx6aDI2BQ7xW92'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '3DiDSECUqqY1AuBP8qtaIa', 'name': 'Alicia Keys'}],
#     'id': '2Ie7pnF3ZKNTde30TQWlWx',
#     'name': 'Like Home (feat. Alicia Keys)',
#     'uri': 'spotify:track:2Ie7pnF3ZKNTde30TQWlWx'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '3NPpFNZtSTHheNBaWC82rB', 'name': 'X Ambassadors'}],
#     'id': '3GOjD8hwXOxbTF3apTqSqX',
#     'name': 'Bad Husband (feat. X Ambassadors)',
#     'uri': 'spotify:track:3GOjD8hwXOxbTF3apTqSqX'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '4utLUGcTvOJFr6aqIJtYWV', 'name': 'Skylar Grey'}],
#     'id': '3xpTHrC1b6dmiLEeM5jO0z',
#     'name': 'Tragic Endings (feat. Skylar Grey)',
#     'uri': 'spotify:track:3xpTHrC1b6dmiLEeM5jO0z'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '4UTpObwAYO67yymOoCeXwS',
#     'name': 'Framed',
#     'uri': 'spotify:track:4UTpObwAYO67yymOoCeXwS'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '0cGUm45nv7Z6M6qdXYQGTX', 'name': 'Kehlani'}],
#     'id': '4xs1uoAjiWAEecX9yKGSF6',
#     'name': 'Nowhere Fast (feat. Kehlani)',
#     'uri': 'spotify:track:4xs1uoAjiWAEecX9yKGSF6'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '7ntU619k40YVxcRvFNDTNn',
#     'name': 'Heat',
#     'uri': 'spotify:track:7ntU619k40YVxcRvFNDTNn'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6ogACNVtzSJHzqLhzUegaf',
#     'name': 'Offended',
#     'uri': 'spotify:track:6ogACNVtzSJHzqLhzUegaf'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '5psTfOBPmc8UquYcnS22KE', 'name': 'Pink'}],
#     'id': '6B2ERbVUDfIiUNXCWhjzFG',
#     'name': 'Need Me (feat. Pink)',
#     'uri': 'spotify:track:6B2ERbVUDfIiUNXCWhjzFG'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '5qykEZTHAcplCLrynoLRnN',
#     'name': 'In Your Head',
#     'uri': 'spotify:track:5qykEZTHAcplCLrynoLRnN'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '0lc70Jh2s1iOMuv9XIEhFy',
#     'name': 'Castle',
#     'uri': 'spotify:track:0lc70Jh2s1iOMuv9XIEhFy'}},
#   {'track': {'album': {'name': 'Revival',
#      'release_date': '2017-12-15',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3fYptFSlH8Xs7Uoybytyrm',
#     'name': 'Arose',
#     'uri': 'spotify:track:3fYptFSlH8Xs7Uoybytyrm'}},
#   {'track': {'album': {'name': 'Nowhere Fast (feat. Kehlani) [Extended Version]',
#      'release_date': '2018-03-17',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '0cGUm45nv7Z6M6qdXYQGTX', 'name': 'Kehlani'}],
#     'id': '1pRjlrQMZYo1K5i1RcLGs7',
#     'name': 'Nowhere Fast (feat. Kehlani) - Extended Version',
#     'uri': 'spotify:track:1pRjlrQMZYo1K5i1RcLGs7'}},
#   {'track': {'album': {'name': 'Southpaw (Music From And Inspired By The Motion Picture)',
#      'release_date': '2015-07-24',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'},
#      {'id': '4yiQZ8tQPux8cPriYMWUFP', 'name': 'Gwen Stefani'}],
#     'id': '3FLPAAlQNb570TtFQ50RwR',
#     'name': 'Kings Never Die (feat. Gwen Stefani)',
#     'uri': 'spotify:track:3FLPAAlQNb570TtFQ50RwR'}},
#   {'track': {'album': {'name': 'Untouchable',
#      'release_date': '2017-12-08',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '6IvespQWGW4USXwexlVKDm',
#     'name': 'Untouchable',
#     'uri': 'spotify:track:6IvespQWGW4USXwexlVKDm'}},
#   {'track': {'album': {'name': 'The Slim Shady LP',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '3GhcNCBIEMyrcpCJ8ccvXr',
#     'name': 'Public Service Announcement',
#     'uri': 'spotify:track:3GhcNCBIEMyrcpCJ8ccvXr'}},
#   {'track': {'album': {'name': 'The Slim Shady LP',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day'},
#     'artists': [{'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem'}],
#     'id': '75IN3CtuZwTHTnZvYM4qnJ',
#     'name': 'My Name Is',
#     'uri': 'spotify:track:75IN3CtuZwTHTnZvYM4qnJ'}},
#   ...]}

# %%
playlist_info.keys()

# %% [markdown]
# ## Producer

# %%
import pika

connection = pika.BlockingConnection(
    pika.ConnectionParameters(host='localhost'))
channel = connection.channel()

channel.queue_declare(queue='playlist')

channel.basic_publish(exchange='', routing_key='playlist', body=json.dumps(playlist_info))
print(" [x] Sent 'Hello World!'")
connection.close()
# Out:
#  [x] Sent 'Hello World!'

# %% [markdown]
# ## Consumer

# %%
import pika, sys
from pymongo import MongoClient

client: MongoClient = MongoClient("mongodb://127.0.0.1:27017/?directConnection=true&serverSelectionTimeoutMS=2000&appName=mongosh+2.1.1")

def save_counter_to_db(playlist_id: str, num_songs: int) -> None:
    db = client.playlist
    collection = db.playlist_counter
    collection.insert_one({"playlist_id": playlist_id, "num_songs":num_songs})
    return

def save_json_to_db(playlist_info: dict[str, str | list[dict[str, Any]]]) -> None:
    playlist_info["tracks"] = [track.get("id") for track in playlist_info["tracks"]]
    db = client.playlist
    collection = db.playlist_info
    collection.insert_one(playlist_info)
    return

def send_messages_for_each_song(playlist_info: dict[str, str | list[dict[str]]]) -> None:
    connection = pika.BlockingConnection(pika.ConnectionParameters(host='localhost'))
    channel = connection.channel()

    channel.queue_declare(queue='tracks')

    for track in playlist_info.get("tracks"):
        channel.basic_publish(exchange='', routing_key='tracks', body=json.dumps(track))
        print(" [x] Sent 'Hello World!'")
    connection.close()

def playlist_consumer_producer():
    connection = pika.BlockingConnection(pika.ConnectionParameters(host='localhost'))
    channel = connection.channel()

    channel.queue_declare(queue='playlist')

    def playlist_unpack(ch, method, properties, body):
        body = json.loads(body)
        save_counter_to_db(body.get("playlist_id"), body.get("num_songs"))
        save_json_to_db(body)
        send_messages_for_each_song(body)
        
        print(f" [x] playlist id: {body.get('playlist_id')} - Total number of songs in the playlist: {body.get('num_songs')}")
        # print(f" [x] Received {body}")

    channel.basic_consume(queue='playlist', on_message_callback=playlist_unpack, auto_ack=True)

    print(' [*] Waiting for messages. To exit press CTRL+C')
    channel.start_consuming()


playlist_consumer_producer()
# Out:
#  [*] Waiting for messages. To exit press CTRL+C
#  [x] playlist id: 31LTVcI9mBggtLVlYRStnJ - Total number of songs in the playlist: 1155

# %%
db.test.insert_one({"nome": "porcodio", "a": "b", "c": 2})
# Out:
# InsertOneResult(ObjectId('65969e449a878c6e2a16d8c2'), acknowledged=True)

# %%
type(client.playlist.test.find_one({"a": "b"}))
# Out:
# dict

# %%
db = client.playlist
collection = db.test

# db.test.insert_one({"nome": "porcodio", "a": "b", "c": 2})
# 
next(db.test.find())
# Out:
# {'_id': ObjectId('65969c4c9a878c6e2a16d8c1'),
#  'nome': 'porcodio',
#  'a': 'b',
#  'c': 2}

# %%
collection.update_one({"nome": "porcodio"}, {"$set": {"a": "bb"}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
